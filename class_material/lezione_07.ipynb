# %%
import pandas as pd

# %%
filepath = 'https://raw.githubusercontent.com/andreagiussani/Applied_Machine_Learning_with_Python/master/data/election.csv'

# %%
my_df = pd.read_csv(filepath)

# %% [markdown]
# ## Data Enrichment and Transformation

# %%
my_df.head()
# Out:
#       county state   total      Obama     Romney  winner  voters    turnout  \
# 0      Adams    PA   41973  35.482334  63.112001  Romney   61156  68.632677
# 1  Allegheny    PA  614671  56.640219  42.185820   Obama  924351  66.497575
# 2  Armstrong    PA   28322  30.696985  67.901278  Romney   42147  67.198140
# 3     Beaver    PA   80015  46.032619  52.637630  Romney  115157  69.483401
# 4    Bedford    PA   21444  22.057452  76.986570  Romney   32189  66.619031
#
#       margin
# 0  27.629667
# 1  14.454399
# 2  37.204293
# 3   6.605012
# 4  54.929118

# %%
cond_one = my_df.voters > 70000
my_df['new_col'] = cond_one

# %%
type(my_df)
# Out:
# pandas.core.frame.DataFrame

# %%
my_list = ['A','B','C']
for idx, x in enumerate(my_list):
  print(idx, x.lower())
# Out:
# 0 a
# 1 b
# 2 c

# %%
[x.lower() for idx, x in enumerate(my_list)]
# Out:
# ['a', 'b', 'c']

# %%
# %%timeit
my_new_list = []
for idx, row in my_df.iterrows():
  row_winner = row.winner.lower()
  my_new_list.append(row_winner)
# Out:
# 3.4 ms ± 679 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
my_df['new_col_2'] = my_new_list

# %%
# %%timeit
my_df['new_col_2'] = my_df['winner'].apply(lambda x: x.lower())
# Out:
# 347 µs ± 52.2 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
# %%timeit
my_df['new_col_2'] = [x.winner.lower() for idx, x in my_df.iterrows()]
# Out:
# 3.66 ms ± 504 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
my_df.head()
# Out:
#       county state   total      Obama     Romney  winner  voters    turnout  \
# 0      Adams    PA   41973  35.482334  63.112001  Romney   61156  68.632677
# 1  Allegheny    PA  614671  56.640219  42.185820   Obama  924351  66.497575
# 2  Armstrong    PA   28322  30.696985  67.901278  Romney   42147  67.198140
# 3     Beaver    PA   80015  46.032619  52.637630  Romney  115157  69.483401
# 4    Bedford    PA   21444  22.057452  76.986570  Romney   32189  66.619031
#
#       margin  new_col new_col_2
# 0  27.629667    False    romney
# 1  14.454399     True     obama
# 2  37.204293    False    romney
# 3   6.605012     True    romney
# 4  54.929118    False    romney

# %% [markdown]
# ### Mapping

# %%
my_dict = {
    'romney': 'red',
    'obama': 'blue'
}

# %%
my_df['new_col_3'] = my_df['new_col_2'].map(my_dict)

# %%
my_df.head()
# Out:
#       county state   total      Obama     Romney  winner  voters    turnout  \
# 0      Adams    PA   41973  35.482334  63.112001  Romney   61156  68.632677
# 1  Allegheny    PA  614671  56.640219  42.185820   Obama  924351  66.497575
# 2  Armstrong    PA   28322  30.696985  67.901278  Romney   42147  67.198140
# 3     Beaver    PA   80015  46.032619  52.637630  Romney  115157  69.483401
# 4    Bedford    PA   21444  22.057452  76.986570  Romney   32189  66.619031
#
#       margin  new_col new_col_2 new_col_3
# 0  27.629667    False    romney       red
# 1  14.454399     True     obama      blue
# 2  37.204293    False    romney       red
# 3   6.605012     True    romney       red
# 4  54.929118    False    romney       red

# %%
my_df.shape
# Out:
# (67, 12)

# %% [markdown]
# ## Manipulation

# %%
my_df2 = pd.pivot(
    data=my_df,
    index='state',
    columns='county',
    values='winner'
)

# %%
my_df2 = my_df.pivot(
    index='state',
    columns='county',
    values='winner'
)

# %%
my_df2
# Out:
# county   Adams Allegheny Armstrong  Beaver Bedford   Berks   Blair Bradford  \
# state
# PA      Romney     Obama    Romney  Romney  Romney  Romney  Romney   Romney
#
# county  Bucks  Butler  ... Susquehanna   Tioga   Union Venango  Warren  \
# state                  ...
# PA      Obama  Romney  ...      Romney  Romney  Romney  Romney  Romney
#
# county Washington   Wayne Westmoreland Wyoming    York
# state
# PA         Romney  Romney       Romney  Romney  Romney
#
# [1 rows x 67 columns]

# %%
new_df_pivot = my_df.pivot(
    index='county',
    columns='winner',
    values='margin'
).fillna(0)

# %%
my_df.pivot(
    index=['county', 'new_col_3'],
    columns='state',
    values=['Obama',	'Romney']
).fillna(0).head()
# Out:
#                          Obama     Romney
# state                       PA         PA
# county    new_col_3
# Adams     red        35.482334  63.112001
# Allegheny blue       56.640219  42.185820
# Armstrong red        30.696985  67.901278
# Beaver    red        46.032619  52.637630
# Bedford   red        22.057452  76.986570

# %% [markdown]
# In quante province ha vinto Obama e quante Romney?

# %%
my_df['winner'].value_counts()
# Out:
# Romney    55
# Obama     12
# Name: winner, dtype: int64

# %%
my_df.pivot_table(
    index=['winner'],
    columns='state',
    values='voters',
    aggfunc='count'
)
# Out:
# state   PA
# winner
# Obama   12
# Romney  55

# %% [markdown]
# calcolo la media dei voters per candidato sulle province

# %%
my_df.pivot_table(
    index=['winner'],
    columns='state',
    values='voters',
    aggfunc='mean'
)
# Out:
# state              PA
# winner
# Obama   387644.083333
# Romney   70114.290909

# %%
my_df.pivot_table(
    index=['winner'],
    columns='state',
    values='voters',
    aggfunc='max'
)
# Out:
# state        PA
# winner
# Obama   1099197
# Romney   337822

# %% [markdown]
# ## Un nuovo dataset da usare

# %%
filepath = 'https://raw.githubusercontent.com/andreagiussani/Applied_Machine_Learning_with_Python/master/data/titanic.csv'
titanic_df = pd.read_csv(filepath)

# %%
titanic_df = pd.read_csv(filepath)

# %%
titanic_df.Pclass.value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic_df.pivot_table(
    index='Pclass',
    columns='Embarked',
    values=['Fare', 'Age'],
    aggfunc=['mean', 'median']
)
# Out:
#                mean                                                        \
#                 Age                            Fare
# Embarked          C        Q          S           C          Q          S
# Pclass
# 1         38.027027  38.5000  38.152037  104.718529  90.000000  70.364862
# 2         22.766667  43.5000  30.386731   25.358335  12.350000  20.327439
# 3         20.741951  25.9375  25.696552   11.214083  11.183393  14.644083
#
#          median
#             Age                 Fare
# Embarked      C     Q     S        C      Q      S
# Pclass
# 1          36.5  38.5  37.0  78.2667  90.00  52.00
# 2          25.0  43.5  30.0  24.0000  12.35  13.50
# 3          20.0  21.5  25.0   7.8958   7.75   8.05

# %%
titanic_df.pivot_table(
    ['Fare', 'Age'],
    index='Pclass',
    aggfunc=['mean', 'median']
)
# Out:
#              mean            median
#               Age       Fare    Age     Fare
# Pclass
# 1       38.233441  84.154687   37.0  60.2875
# 2       29.877630  20.662183   29.0  14.2500
# 3       25.140620  13.675550   24.0   8.0500

# %%
titanic_df[['Pclass', 'Fare', 'Age']].groupby('Pclass')['Fare', 'Age'].agg(['mean', 'median'])
# Out:
# <ipython-input-107-41416ff0ac86>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   titanic_df[['Pclass', 'Fare', 'Age']].groupby('Pclass')['Fare', 'Age'].agg(['mean', 'median'])
#              Fare                 Age
#              mean   median       mean median
# Pclass
# 1       84.154687  60.2875  38.233441   37.0
# 2       20.662183  14.2500  29.877630   29.0
# 3       13.675550   8.0500  25.140620   24.0

# %% [markdown]
# Calcolare media della survival tra genere ('Sex') e Pclass

# %%
titanic_df[['Pclass', 'Sex', 'Survived']].groupby(['Pclass', 'Sex']).agg(['mean'])
# Out:
#                Survived
#                    mean
# Pclass Sex
# 1      female  0.968085
#        male    0.368852
# 2      female  0.921053
#        male    0.157407
# 3      female  0.500000
#        male    0.135447

# %%
titanic_df.pivot_table(
    'Survived',
    index=['Pclass', 'Sex'],
    aggfunc='mean',
)
# Out:
#                Survived
# Pclass Sex
# 1      female  0.968085
#        male    0.368852
# 2      female  0.921053
#        male    0.157407
# 3      female  0.500000
#        male    0.135447

# %%
titanic_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
# home: vedere a quale classe appartengono le persone per il quale l'eta non è stata identificata

# %% [markdown]
# ## Imputazione dei Missing Values con Scikit-learn

# %%
from sklearn.impute import SimpleImputer

# %%
si = SimpleImputer()
pd.DataFrame(si.fit_transform(titanic_df[['PassengerId', 'Age']]))
# Out:
#          0          1
# 0      1.0  22.000000
# 1      2.0  38.000000
# 2      3.0  26.000000
# 3      4.0  35.000000
# 4      5.0  35.000000
# ..     ...        ...
# 886  887.0  27.000000
# 887  888.0  19.000000
# 888  889.0  29.699118
# 889  890.0  26.000000
# 890  891.0  32.000000
#
# [891 rows x 2 columns]
